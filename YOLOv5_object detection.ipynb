# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-270-g4733b4d Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !unzip /content/YOLO.zip -d ../
# Out:
# Archive:  /content/YOLO.zip
#    creating: ../YOLO/
#    creating: ../YOLO/images/
#    creating: ../YOLO/images/train/
#   inflating: ../YOLO/images/train/1.jpg
#   inflating: ../YOLO/images/train/10.jpg
#   inflating: ../YOLO/images/train/11.jpg
#   inflating: ../YOLO/images/train/12.jpg
#   inflating: ../YOLO/images/train/13.jpg
#   inflating: ../YOLO/images/train/14.jpg
#   inflating: ../YOLO/images/train/15.jpg
#   inflating: ../YOLO/images/train/16.jpg
#   inflating: ../YOLO/images/train/17.jpg
#   inflating: ../YOLO/images/train/18.jpg
#   inflating: ../YOLO/images/train/19.jpg
#   inflating: ../YOLO/images/train/2.jpg
#   inflating: ../YOLO/images/train/20.jpg
#   inflating: ../YOLO/images/train/21.jpg
#   inflating: ../YOLO/images/train/22.jpg
#   inflating: ../YOLO/images/train/23.jpg
#   inflating: ../YOLO/images/train/24.jpg
#   inflating: ../YOLO/images/train/27.jpg
#   inflating: ../YOLO/images/train/28.jpg
#   inflating: ../YOLO/images/train/29.jpg
# ...

# %%
# !python train.py --img 640 --batch 2 --epoch 80 --data /content/yolov5/data/custom_data.yaml  --weights yolov5s.pt --nosave --cache
# Out:
# 2024-01-08 20:18:49.349634: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-08 20:18:49.349681: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-08 20:18:49.351121: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source /content/demovideo.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/last.pt'], source=/content/demovideo.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-270-g4733b4d Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/445) /content/demovideo.mp4: 384x640 (no detections), 46.3ms
# video 1/1 (2/445) /content/demovideo.mp4: 384x640 (no detections), 7.4ms
# video 1/1 (3/445) /content/demovideo.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (4/445) /content/demovideo.mp4: 384x640 (no detections), 7.4ms
# ...
